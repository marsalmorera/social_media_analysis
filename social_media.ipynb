# %% [markdown]
# <h1 style= "color:#9370DB;"> Stock Analysis </h1>

# %%
# 📚 Libraries 
import kagglehub
import pandas as pd
import numpy as np
import os

# 📊 Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as g

# %% [markdown]
# ### The Stock Analysis Dataset:
#
#
# **First impressions:**
#
# _____________
#
# The **S&P 500** is a stock market index tracking the performance of the largest 500 publicly traded companies listed on U.S. stock exchanges.
#
# Investors have long used the S&P 500 as a benchmark for their investments as it tends to signal overall market health.
# The index is a popular choice for long-term inverstors who wish to watch growth over the coming deacades.
#
# The dataset contains:
# - S&P 500 **Index**: Contains the daily price of the index, representing the overall performance of the 500 companies in the S&P 500.
# - S&P 500 **Stocks**: Includes the daily stock prices for each company within the index, providing insights into individual stock movements.
# - S&P 500 **Companies**: Provides detailed information about each company, including metrics such as Name, Sector, Marketcap, Ebitda, Weight.
#
# The data types are even: (13 int or float / 13 objects).
#
# Our **project goal** is to identify the performance of various sectors in the S&P 500. After reading the [documentation](https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks) we will proceed with the following **strategy**:
#
# 1. The **target** of our dataset will be `currentprice`, which is the actual price of the stock right now.
# 2. Through **Exploratory Data Analysis** we will identify the performance of various sectors and stocks.

# %% [markdown]
# <h2 style="color: #9370DB;"> 01 | Data Extraction </h2>

# %%
data = pd.read_csv('social_media_entertainment_data.csv')

# %%
# Cleaning columns with snake_case 
data.columns = [col.lower().replace(" ", "_")for col in data.columns]

# %% [markdown]
# <h3 style="color: #4169E1;">1.1 | Exploring the Data </h3>

# %%
data
# Out:
#         user_id  age  gender  country  daily_social_media_time_(hrs)  \
# 0             1   32   Other  Germany                           4.35
# 1             2   62   Other    India                           4.96
# 2             3   51  Female      USA                           6.78
# 3             4   44  Female    India                           5.06
# 4             5   21   Other  Germany                           2.57
# ...         ...  ...     ...      ...                            ...
# 299995   299996   17  Female   Canada                           1.98
# 299996   299997   45  Female  Germany                           3.78
# 299997   299998   45    Male   Canada                           6.25
# 299998   299999   15    Male      USA                           6.47
# 299999   300000   49   Other  Germany                           1.27
#
#         daily_entertainment_time_(hrs)  social_media_platforms_used  \
# 0                                 4.08                            5
# 1                                 4.21                            2
# 2                                 1.77                            4
# 3                                 9.21                            3
# 4                                 1.30                            4
# ...                                ...                          ...
# 299995                            8.41                            1
# 299996                            2.18                            2
# 299997                            4.63                            1
# 299998                            2.34                            4
# 299999                            5.17                            4
#
#        primary_platform  daily_messaging_time_(hrs)  \
# 0                TikTok                        0.35
# 1               YouTube                        2.55
# 2              Facebook                        2.09
# 3               YouTube                        3.69
# 4                TikTok                        3.97
# ...                 ...                         ...
# 299995          Twitter                        2.37
# 299996          YouTube                        3.15
# 299997         Facebook                        4.16
# 299998          YouTube                        2.83
# 299999         Facebook                        3.30
#
#         daily_video_content_time_(hrs)  ...  ad_interaction_count  \
# 0                                 5.43  ...                    20
# 1                                 4.22  ...                    26
# 2                                 1.09  ...                    47
# 3                                 4.80  ...                    22
# 4                                 2.74  ...                    42
# ...                                ...  ...                   ...
# 299995                            5.25  ...                    42
# 299996                            6.84  ...                    16
# 299997                            2.43  ...                    24
# 299998                            5.10  ...                    35
# 299999                            3.07  ...                    26
#
#        time_on_educational_platforms_(hrs) parental_status  \
# 0                                     4.11             Yes
# 1                                     4.59             Yes
# 2                                     0.66             Yes
# 3                                     3.44             Yes
# 4                                     4.14             Yes
# ...                                    ...             ...
# 299995                                2.15             Yes
# 299996                                0.02              No
# 299997                                1.88             Yes
# 299998                                0.96              No
# 299999                                3.00             Yes
#
#         tech_savviness_level_(scale_1-10) preferred_device_for_entertainment  \
# 0                                       9                             Tablet
# 1                                       9                                 PC
# 2                                       9                             Tablet
# 3                                       7                             Tablet
# 4                                       7                           Smart TV
# ...                                   ...                                ...
# 299995                                  7                             Tablet
# 299996                                  8                           Smart TV
# 299997                                  6                             Tablet
# 299998                                  7                           Smart TV
# 299999                                  4                           Smart TV
#
#         data_plan_used  digital_well-being_awareness  \
# 0                 50GB                      Moderate
# 1                 10GB                           Low
# 2                 10GB                          High
# 3                 10GB                           Low
# 4            Unlimited                           Low
# ...                ...                           ...
# 299995            10GB                           Low
# 299996            50GB                           Low
# 299997            10GB                      Moderate
# 299998            10GB                          High
# 299999            50GB                           Low
#
#         sleep_quality_(scale_1-10)  social_isolation_feeling_(scale_1-10)  \
# 0                                7                                      8
# 1                                8                                      2
# 2                                5                                      3
# 3                                9                                      9
# 4                                5                                      9
# ...                            ...                                    ...
# 299995                           5                                      8
# 299996                           7                                      8
# 299997                           1                                      8
# 299998                           7                                      5
# 299999                           1                                      7
#
#         monthly_expenditure_on_entertainment_(usd)
# 0                                            33.04
# 1                                           497.78
# 2                                            71.72
# 3                                           129.62
# 4                                            35.90
# ...                                            ...
# 299995                                       47.46
# 299996                                      479.79
# 299997                                       53.05
# 299998                                      432.00
# 299999                                      104.74
#
# [300000 rows x 40 columns]

# %% [markdown]
# ### Dataset Description:
#
# A brief analysis of each column.
# - `Date`: The specific date for which the stock date is recorded.
# - `Symbol`: A unique "ticker" code that identifies the company on the stock exchange.
# - `Adj_close`: The closing price of the stock after adjustments for dividends, splits, or other corporate actions.
# - `Close`: The unadjusted closing price of the stock on a given date.
# - `High`: The highest price at which the stock traded during the day.
# - `Low`: The lowest price at which the stock traded during the day.
# - `Open`: The price at which the stock started trading at the beginning of the day.
# - `Volume`: The total number of shares traded during the day.

# %% [markdown]
# <h3 style="color: #4169E1;">1.2 | Copies</h3>

# %%
df = data.copy()

# %% [markdown]
# <h2 style="color: #9370DB;"> 02 | Data Cleaning </h2>

# %% [markdown]
# <h3 style="color: #4169E1;"> 2.1 | Dealing with Data types</h3>

# %%
data.dtypes
# Out:
# user_id                                         int64
# age                                             int64
# gender                                         object
# country                                        object
# daily_social_media_time_(hrs)                 float64
# daily_entertainment_time_(hrs)                float64
# social_media_platforms_used                     int64
# primary_platform                               object
# daily_messaging_time_(hrs)                    float64
# daily_video_content_time_(hrs)                float64
# daily_gaming_time_(hrs)                       float64
# occupation                                     object
# marital_status                                 object
# monthly_income_(usd)                          float64
# device_type                                    object
# internet_speed_(mbps)                         float64
# subscription_platforms                          int64
# average_sleep_time_(hrs)                      float64
# physical_activity_time_(hrs)                  float64
# reading_time_(hrs)                            float64
# work/study_time_(hrs)                         float64
# screen_time_(hrs)                             float64
# notifications_received_daily                    int64
# daily_music_listening_time_(hrs)              float64
# preferred_content_type                         object
# primary_social_media_goal                      object
# preferred_entertainment_platform               object
# time_spent_in_online_communities_(hrs)        float64
# social_media_fatigue_level_(scale_1-10)         int64
# news_consumption_time_(hrs)                   float64
# ad_interaction_count                            int64
# time_on_educational_platforms_(hrs)           float64
# parental_status                                object
# tech_savviness_level_(scale_1-10)               int64
# preferred_device_for_entertainment             object
# data_plan_used                                 object
# digital_well-being_awareness                   object
# sleep_quality_(scale_1-10)                      int64
# social_isolation_feeling_(scale_1-10)           int64
# monthly_expenditure_on_entertainment_(usd)    float64
# dtype: object

# %% [markdown]
# <h3 style="color: #4169E1;"> 2.2 | Dealing with NaN values</h3>

# %%
df.isna().sum()
# Out:
# user_id                                       0
# age                                           0
# gender                                        0
# country                                       0
# daily_social_media_time_(hrs)                 0
# daily_entertainment_time_(hrs)                0
# social_media_platforms_used                   0
# primary_platform                              0
# daily_messaging_time_(hrs)                    0
# daily_video_content_time_(hrs)                0
# daily_gaming_time_(hrs)                       0
# occupation                                    0
# marital_status                                0
# monthly_income_(usd)                          0
# device_type                                   0
# internet_speed_(mbps)                         0
# subscription_platforms                        0
# average_sleep_time_(hrs)                      0
# physical_activity_time_(hrs)                  0
# reading_time_(hrs)                            0
# work/study_time_(hrs)                         0
# screen_time_(hrs)                             0
# notifications_received_daily                  0
# daily_music_listening_time_(hrs)              0
# preferred_content_type                        0
# primary_social_media_goal                     0
# preferred_entertainment_platform              0
# time_spent_in_online_communities_(hrs)        0
# social_media_fatigue_level_(scale_1-10)       0
# news_consumption_time_(hrs)                   0
# ad_interaction_count                          0
# time_on_educational_platforms_(hrs)           0
# parental_status                               0
# tech_savviness_level_(scale_1-10)             0
# preferred_device_for_entertainment            0
# data_plan_used                                0
# digital_well-being_awareness                  0
# sleep_quality_(scale_1-10)                    0
# social_isolation_feeling_(scale_1-10)         0
# monthly_expenditure_on_entertainment_(usd)    0
# dtype: int64

# %% [markdown]
# <h3 style="color: #4169E1;"> 2.3 | Dealing with Duplicates</h3>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h3 style="color: #4169E1;"> 2.4 | Dealing with columns </h3>

# %%
# Delete Columns 
data2.drop(columns=['high', 'low', 'open','close'], inplace=True)

# %% [markdown]
# <h3 style="color: #4169E1;"> 2.5 | Moving target to the right </h3>

# %% [markdown]
# <h2 style="color: #9370DB;"> 03 | EDA (Exploratory Data Analysis) </h2>

# %% [markdown]
# <h3 style="color: #4169E1;">3.1 | Descriptive Statistics </h3>

# %% [markdown]
# <h3 style="color: #4169E1;"> 3.2 | Checking Distributions</h3>

# %% [markdown]
# <h3 style="color: #4169E1;"> 3.3 | Checking our target distribution</h3>

# %% [markdown]
# <h3 style="color: #4169E1;">3.4 | Checking Outliers </h3>

# %% [markdown]
# <h3 style="color: #4169E1;">3.5 | Looking for Correlations </h3>

# %% [markdown]
# <h2 style="color: #9370DB;"> 04 | Data Processing Optional</h2>

# %% [markdown]
# <h3 style="color: #4169E1;"> 4.1 | X-Y Split</h3>

# %% [markdown]
# <h3 style="color: #4169E1;"> 4.2 | Selecting the Model</h3>
